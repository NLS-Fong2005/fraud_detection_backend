# %% [markdown]
# #### **Importing Libraries and Dataset**

# %%
import pandas as pd

# %%
import os

raw_data_source_path: str = os.path.abspath("../data/raw/spam.csv")

raw_dataframe: pd.DataFrame = pd.read_csv(raw_data_source_path)

# %% [markdown]
# #### **Data Exploration**

# %%
raw_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
display(raw_dataframe.head())
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# **Missing Values**

# %%
raw_dataframe.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %% [markdown]
# Data is complete without any missing values, data cleaning is unneeded.

# %% [markdown]
# **Sum of Categories**

# %%
raw_dataframe['Category'].value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64
